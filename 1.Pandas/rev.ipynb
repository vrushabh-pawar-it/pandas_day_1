# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\91942\Desktop\11.11\agree\SNOW\pandas\datasets1\datasets1\empdata.csv')
df
# Out:
#    empid           ename       sal         doj
# 0   1001      Ganesh Rao  10000.00  2000-10-10
# 1   1002      Anil Kumar  23000.50  2002-03-03
# 2   1003    Gaurav Gupta  18000.33  2002-03-03
# 3   1004    Hema Chandra  16500.50  2002-03-03
# 4   1005  Laxmi Prasanna  12000.75  2000-08-10
# 5   1006       Anant Nag   9999.99  1999-09-09

# %%
df.head()
# Out:
#    empid           ename       sal         doj
# 0   1001      Ganesh Rao  10000.00  2000-10-10
# 1   1002      Anil Kumar  23000.50  2002-03-03
# 2   1003    Gaurav Gupta  18000.33  2002-03-03
# 3   1004    Hema Chandra  16500.50  2002-03-03
# 4   1005  Laxmi Prasanna  12000.75  2000-08-10

# %%
df.tail()
# Out:
#    empid           ename       sal         doj
# 1   1002      Anil Kumar  23000.50  2002-03-03
# 2   1003    Gaurav Gupta  18000.33  2002-03-03
# 3   1004    Hema Chandra  16500.50  2002-03-03
# 4   1005  Laxmi Prasanna  12000.75  2000-08-10
# 5   1006       Anant Nag   9999.99  1999-09-09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   empid   6 non-null      int64
#  1   ename   6 non-null      object
#  2   sal     6 non-null      float64
#  3   doj     6 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 324.0+ bytes

# %%
df.isnull()
# Out:
#    empid  ename    sal    doj
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False  False
# 5  False  False  False  False

# %%
df.fillna(0)
# Out:
#    empid           ename       sal         doj
# 0   1001      Ganesh Rao  10000.00  2000-10-10
# 1   1002      Anil Kumar  23000.50  2002-03-03
# 2   1003    Gaurav Gupta  18000.33  2002-03-03
# 3   1004    Hema Chandra  16500.50  2002-03-03
# 4   1005  Laxmi Prasanna  12000.75  2000-08-10
# 5   1006       Anant Nag   9999.99  1999-09-09

# %%
df.loc[0]
# Out:
# empid          1001
# ename    Ganesh Rao
# sal         10000.0
# doj      2000-10-10
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# empid          1001
# ename    Ganesh Rao
# sal         10000.0
# doj      2000-10-10
# Name: 0, dtype: object

# %%
df['doj']
# Out:
# 0    2000-10-10
# 1    2002-03-03
# 2    2002-03-03
# 3    2002-03-03
# 4    2000-08-10
# 5    1999-09-09
# Name: doj, dtype: object

# %%
df[['doj', 'empid']]
# Out:
#           doj  empid
# 0  2000-10-10   1001
# 1  2002-03-03   1002
# 2  2002-03-03   1003
# 3  2002-03-03   1004
# 4  2000-08-10   1005
# 5  1999-09-09   1006

# %%
df[df['empid'] > 10 ]
# Out:
#    empid           ename       sal         doj
# 0   1001      Ganesh Rao  10000.00  2000-10-10
# 1   1002      Anil Kumar  23000.50  2002-03-03
# 2   1003    Gaurav Gupta  18000.33  2002-03-03
# 3   1004    Hema Chandra  16500.50  2002-03-03
# 4   1005  Laxmi Prasanna  12000.75  2000-08-10
# 5   1006       Anant Nag   9999.99  1999-09-09

# %%
df[(df['empid'] > 1005) & (df['sal'] > 10000)]
# Out:
# Empty DataFrame
# Columns: [empid, ename, sal, doj]
# Index: []

# %%
df.sort_values('sal', ascending=False)
# Out:
#    empid           ename       sal         doj
# 1   1002      Anil Kumar  23000.50  2002-03-03
# 2   1003    Gaurav Gupta  18000.33  2002-03-03
# 3   1004    Hema Chandra  16500.50  2002-03-03
# 4   1005  Laxmi Prasanna  12000.75  2000-08-10
# 0   1001      Ganesh Rao  10000.00  2000-10-10
# 5   1006       Anant Nag   9999.99  1999-09-09

# %%
df.sort_values('sal', ascending=False).head(5)
# Out:
#    empid           ename       sal         doj
# 1   1002      Anil Kumar  23000.50  2002-03-03
# 2   1003    Gaurav Gupta  18000.33  2002-03-03
# 3   1004    Hema Chandra  16500.50  2002-03-03
# 4   1005  Laxmi Prasanna  12000.75  2000-08-10
# 0   1001      Ganesh Rao  10000.00  2000-10-10

# %%
df.query('empid > 1')
# Out:
#    empid           ename       sal         doj
# 0   1001      Ganesh Rao  10000.00  2000-10-10
# 1   1002      Anil Kumar  23000.50  2002-03-03
# 2   1003    Gaurav Gupta  18000.33  2002-03-03
# 3   1004    Hema Chandra  16500.50  2002-03-03
# 4   1005  Laxmi Prasanna  12000.75  2000-08-10
# 5   1006       Anant Nag   9999.99  1999-09-09

# %%
df['age'] = [10,20,30,40,50,60]

# %%
df.insert(1, 'custid',[1,2,3,4,5,6,])

# %%
df.rename(columns={'age': 'Age'})
# Out:
#    empid  custid           ename       sal         doj  Age
# 0   1001       1      Ganesh Rao  10000.00  2000-10-10   10
# 1   1002       2      Anil Kumar  23000.50  2002-03-03   20
# 2   1003       3    Gaurav Gupta  18000.33  2002-03-03   30
# 3   1004       4    Hema Chandra  16500.50  2002-03-03   40
# 4   1005       5  Laxmi Prasanna  12000.75  2000-08-10   50
# 5   1006       6       Anant Nag   9999.99  1999-09-09   60

# %%
df.drop('custid', axis = 1)
# Out:
#    empid           ename       sal         doj  age
# 0   1001      Ganesh Rao  10000.00  2000-10-10   10
# 1   1002      Anil Kumar  23000.50  2002-03-03   20
# 2   1003    Gaurav Gupta  18000.33  2002-03-03   30
# 3   1004    Hema Chandra  16500.50  2002-03-03   40
# 4   1005  Laxmi Prasanna  12000.75  2000-08-10   50
# 5   1006       Anant Nag   9999.99  1999-09-09   60

# %%
df.groupby('empid')

# %%
df.groupby('empid').size()
# Out:
# empid
# 1001    1
# 1002    1
# 1003    1
# 1004    1
# 1005    1
# 1006    1
# dtype: int64

# %%
df.groupby('empid')['sal'].mean()
# Out:
# empid
# 1001    10000.00
# 1002    23000.50
# 1003    18000.33
# 1004    16500.50
# 1005    12000.75
# 1006     9999.99
# Name: sal, dtype: float64

# %%
df.groupby('empid').agg({
    'sal':['min','max'],
    'doj':['min', 'max']
})
# Out:
#             sal                   doj
#             min       max         min         max
# empid
# 1001   10000.00  10000.00  2000-10-10  2000-10-10
# 1002   23000.50  23000.50  2002-03-03  2002-03-03
# 1003   18000.33  18000.33  2002-03-03  2002-03-03
# 1004   16500.50  16500.50  2002-03-03  2002-03-03
# 1005   12000.75  12000.75  2000-08-10  2000-08-10
# 1006    9999.99   9999.99  1999-09-09  1999-09-09

# %%
df['doj'].value_counts()
# Out:
# doj
# 2002-03-03    3
# 2000-10-10    1
# 2000-08-10    1
# 1999-09-09    1
# Name: count, dtype: int64

# %%
df['empid'].unique()
# Out:
# array([1001, 1002, 1003, 1004, 1005, 1006])

# %%
df['empid'].nunique()
# Out:
# 6

# %%
df
# Out:
#    empid  custid           ename       sal         doj  age
# 0   1001       1      Ganesh Rao  10000.00  2000-10-10   10
# 1   1002       2      Anil Kumar  23000.50  2002-03-03   20
# 2   1003       3    Gaurav Gupta  18000.33  2002-03-03   30
# 3   1004       4    Hema Chandra  16500.50  2002-03-03   40
# 4   1005       5  Laxmi Prasanna  12000.75  2000-08-10   50
# 5   1006       6       Anant Nag   9999.99  1999-09-09   60

# %%
df.where(df['age'] > 10, 'bad')
# Out:
#   empid custid           ename       sal         doj  age
# 0   bad    bad             bad       bad         bad  bad
# 1  1002      2      Anil Kumar   23000.5  2002-03-03   20
# 2  1003      3    Gaurav Gupta  18000.33  2002-03-03   30
# 3  1004      4    Hema Chandra   16500.5  2002-03-03   40
# 4  1005      5  Laxmi Prasanna  12000.75  2000-08-10   50
# 5  1006      6       Anant Nag   9999.99  1999-09-09   60

# %%
df.groupby('age')['sal'].mean() # here we used () for the age coz we creating a grup by so its a method
# Out:
# age
# 10    10000.00
# 20    23000.50
# 30    18000.33
# 40    16500.50
# 50    12000.75
# 60     9999.99
# Name: sal, dtype: float64
