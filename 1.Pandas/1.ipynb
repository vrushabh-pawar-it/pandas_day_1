# %%
import pandas as pd

# %%
df = pd.read_csv(
    r'C:\Users\91942\Downloads\datasets1\datasets1\textdata.txt',
    sep=r'\s+',
    names=['A', 'B', 'C', 'Person']
)
df
# Out:
#    A  B      C   Person
# 0  1  1   2.92    Vijay
# 1  1  2  70.75    Kumar
# 2  1  3  60.90    Vinay
# 3  2  1  71.34     Anil
# 4  2  2   5.23    Ashok
# 5  2  3  38.56   Neeraj
# 6  3  1  61.24     Sita
# 7  3  2  38.68    Laxmi
# 8  3  3   4.49  Chandra

# %%
df = pd.read_csv(r'C:\Users\91942\Downloads\datasets1\datasets1\empdata1.csv',)
df
# Out:
#    empid           ename       sal       doj
# 0   1001      Ganesh Rao  10000.00  10-10-00
# 1   1002      Anil Kumar  23000.50  03-03-02
# 2   1003             NaN  18000.33  03-03-02
# 3   1004    Hema Chandra       NaN       NaN
# 4   1005  Laxmi Prasanna  12000.75  10-08-00
# 5   1006       Anant Nag   9999.99  09-09-99

# %%
df.loc[:,'ename']
# Out:
# 0        Ganesh Rao
# 1        Anil Kumar
# 2               NaN
# 3      Hema Chandra
# 4    Laxmi Prasanna
# 5         Anant Nag
# Name: ename, dtype: object

# %%
df.loc[:, 'doj']
# Out:
# 0    10-10-00
# 1    03-03-02
# 2    03-03-02
# 3         NaN
# 4    10-08-00
# 5    09-09-99
# Name: doj, dtype: object

# %%
df.iloc[:, 3]
# Out:
# 0    10-10-00
# 1    03-03-02
# 2    03-03-02
# 3         NaN
# 4    10-08-00
# 5    09-09-99
# Name: doj, dtype: object

# %%
df.iloc[:,[3]] # 👉 "Give me all rows (:) from column index 3 (doj)"
# Out:
#         doj
# 0  10-10-00
# 1  03-03-02
# 2  03-03-02
# 3       NaN
# 4  10-08-00
# 5  09-09-99

# %%
# to see more than one column
df.loc[:, ['ename', 'sal', 'doj']]
# Out:
#             ename       sal       doj
# 0      Ganesh Rao  10000.00  10-10-00
# 1      Anil Kumar  23000.50  03-03-02
# 2             NaN  18000.33  03-03-02
# 3    Hema Chandra       NaN       NaN
# 4  Laxmi Prasanna  12000.75  10-08-00
# 5       Anant Nag   9999.99  09-09-99

# %%
# "Display all rows and only the first two columns of the DataFrame."
df.iloc[:,[0,1]]
# Out:
#    empid           ename
# 0   1001      Ganesh Rao
# 1   1002      Anil Kumar
# 2   1003             NaN
# 3   1004    Hema Chandra
# 4   1005  Laxmi Prasanna
# 5   1006       Anant Nag

# %%
# to see range rows
df.loc[2:3, ['ename', 'sal']]
# Out:
#           ename       sal
# 2           NaN  18000.33
# 3  Hema Chandra       NaN

# %%
df.iloc[2:3, [2,3]] # iloc only accept the int not a string
# Out:
#         sal       doj
# 2  18000.33  03-03-02

# %%
df.iloc[0:3, [1,2]]
# Out:
#         ename       sal
# 0  Ganesh Rao  10000.00
# 1  Anil Kumar  23000.50
# 2         NaN  18000.33

# %%
# to display last row
df.iloc[-1]
# Out:
# empid         1006
# ename    Anant Nag
# sal        9999.99
# doj       09-09-99
# Name: 5, dtype: object

# %%
# to retrive last column
df.loc[:,'doj']
# Out:
# 0    10-10-00
# 1    03-03-02
# 2    03-03-02
# 3         NaN
# 4    10-08-00
# 5    09-09-99
# Name: doj, dtype: object

# %%
df.iloc[:, -1]  # "Give me all rows from the last column."
# Out:
# 0    10-10-00
# 1    03-03-02
# 2    03-03-02
# 3         NaN
# 4    10-08-00
# 5    09-09-99
# Name: doj, dtype: object

# %%
# to find the dataset size
df.shape
# Out:
# (6, 4)

# %%
# to display the first 5 rows of a DataFrame.
df.head()
# Out:
#    empid           ename       sal       doj
# 0   1001      Ganesh Rao  10000.00  10-10-00
# 1   1002      Anil Kumar  23000.50  03-03-02
# 2   1003             NaN  18000.33  03-03-02
# 3   1004    Hema Chandra       NaN       NaN
# 4   1005  Laxmi Prasanna  12000.75  10-08-00

# %%
df.tail()  # for last 5 rows
# Out:
#    empid           ename       sal       doj
# 1   1002      Anil Kumar  23000.50  03-03-02
# 2   1003             NaN  18000.33  03-03-02
# 3   1004    Hema Chandra       NaN       NaN
# 4   1005  Laxmi Prasanna  12000.75  10-08-00
# 5   1006       Anant Nag   9999.99  09-09-99

# %%
# display all the columns
df.columns
# Out:
# Index(['empid', 'ename', 'sal', 'doj'], dtype='object')

# %%
# "Display rows from index 2 up to (but not including) index 5."
df[2:5]
# Out:
#    empid           ename       sal       doj
# 2   1003             NaN  18000.33  03-03-02
# 3   1004    Hema Chandra       NaN       NaN
# 4   1005  Laxmi Prasanna  12000.75  10-08-00

# %%
# alternate rows  diff 3
df[::3]
# Out:
#    empid         ename      sal       doj
# 0   1001    Ganesh Rao  10000.0  10-10-00
# 3   1004  Hema Chandra      NaN       NaN

# %%
# display rows reverse number
df[:: -1]
# Out:
#    empid           ename       sal       doj
# 5   1006       Anant Nag   9999.99  09-09-99
# 4   1005  Laxmi Prasanna  12000.75  10-08-00
# 3   1004    Hema Chandra       NaN       NaN
# 2   1003             NaN  18000.33  03-03-02
# 1   1002      Anil Kumar  23000.50  03-03-02
# 0   1001      Ganesh Rao  10000.00  10-10-00

# %%
# alternate rows with col
df[::2][['ename', 'doj','sal']]
# Out:
#             ename       doj       sal
# 0      Ganesh Rao  10-10-00  10000.00
# 2             NaN  03-03-02  18000.33
# 4  Laxmi Prasanna  10-08-00  12000.75

# %%
df # all data are printed
# Out:
#    empid           ename       sal       doj
# 0   1001      Ganesh Rao  10000.00  10-10-00
# 1   1002      Anil Kumar  23000.50  03-03-02
# 2   1003             NaN  18000.33  03-03-02
# 3   1004    Hema Chandra       NaN       NaN
# 4   1005  Laxmi Prasanna  12000.75  10-08-00
# 5   1006       Anant Nag   9999.99  09-09-99

# %%
# to know the max sal
df.sal.max()
# Out:
# np.float64(23000.5)

# %%
# to know the min sal
df.sal.min()
# Out:
# np.float64(9999.99)

# %%
# to display max sal diff way
df['sal'].max()
# Out:
# np.float64(23000.5)

# %%
df.sal.mean()  # mean of sal
# Out:
# np.float64(14600.314000000002)

# %%
df['sal'].mean() # mean of sal
# Out:
# np.float64(14600.314000000002)

# %%
# avg salary
print("the avg sal is = ", df.sal.mean())
# Out:
# the avg sal is =  14600.314000000002

# %%
#  to print stastical info
df.describe()
# Out:
#              empid           sal
# count     6.000000      5.000000
# mean   1003.500000  14600.314000
# std       1.870829   5727.277635
# min    1001.000000   9999.990000
# 25%    1002.250000  10000.000000
# 50%    1003.500000  12000.750000
# 75%    1004.750000  18000.330000
# max    1006.000000  23000.500000

# %%
# sal is greater than 5000  # 2 df for nothingh but the masking
df[df['sal'] > 5000]
# Out:
#    empid           ename       sal       doj
# 0   1001      Ganesh Rao  10000.00  10-10-00
# 1   1002      Anil Kumar  23000.50  03-03-02
# 2   1003             NaN  18000.33  03-03-02
# 4   1005  Laxmi Prasanna  12000.75  10-08-00
# 5   1006       Anant Nag   9999.99  09-09-99

# %%
# in between 10000 and 20000
df[(df['sal']>10000) & (df['sal']<20000)]
# Out:
#    empid           ename       sal       doj
# 2   1003             NaN  18000.33  03-03-02
# 4   1005  Laxmi Prasanna  12000.75  10-08-00

# %%
df[(df['sal']>10000) & (df.sal<20000)]
# Out:
#    empid           ename       sal       doj
# 2   1003             NaN  18000.33  03-03-02
# 4   1005  Laxmi Prasanna  12000.75  10-08-00

# %%
# "Make the empid column the index of the DataFrame and update the original DataFrame.
df.set_index('empid', inplace=True)

# %%
df
# Out:
#                 ename       sal       doj
# empid
# 1001       Ganesh Rao  10000.00  10-10-00
# 1002       Anil Kumar  23000.50  03-03-02
# 1003              NaN  18000.33  03-03-02
# 1004     Hema Chandra       NaN       NaN
# 1005   Laxmi Prasanna  12000.75  10-08-00
# 1006        Anant Nag   9999.99  09-09-99

# %%
# for reset the values empid
df.reset_index('empid', inplace=True)

# %%
df.loc[1]
# Out:
# empid          1002
# ename    Anil Kumar
# sal         23000.5
# doj        03-03-02
# Name: 1, dtype: object

# %%
# sorting desc order
df.sort_values('ename', ascending=False)
# Out:
#    empid           ename       sal       doj
# 4   1005  Laxmi Prasanna  12000.75  10-08-00
# 3   1004    Hema Chandra       NaN       NaN
# 0   1001      Ganesh Rao  10000.00  10-10-00
# 1   1002      Anil Kumar  23000.50  03-03-02
# 5   1006       Anant Nag   9999.99  09-09-99
# 2   1003             NaN  18000.33  03-03-02

# %%
# for sorting indexing
df.sort_values('empid', ascending=False)
# Out:
#    empid           ename       sal       doj
# 5   1006       Anant Nag   9999.99  09-09-99
# 4   1005  Laxmi Prasanna  12000.75  10-08-00
# 3   1004    Hema Chandra       NaN       NaN
# 2   1003             NaN  18000.33  03-03-02
# 1   1002      Anil Kumar  23000.50  03-03-02
# 0   1001      Ganesh Rao  10000.00  10-10-00

# %%
df.sort_values(by = ['doj', 'sal'], ascending=[False, True])
# Out:
#    empid           ename       sal       doj
# 0   1001      Ganesh Rao  10000.00  10-10-00
# 4   1005  Laxmi Prasanna  12000.75  10-08-00
# 5   1006       Anant Nag   9999.99  09-09-99
# 2   1003             NaN  18000.33  03-03-02
# 1   1002      Anil Kumar  23000.50  03-03-02
# 3   1004    Hema Chandra       NaN       NaN
