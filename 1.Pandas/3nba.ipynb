# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\91942\Downloads\datasets1\datasets1\nba.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
s2 = pd.Series(['df.age', 'df.salary'])
s2
# Out:
# 0       df.age
# 1    df.salary
# dtype: object

# %%
s1 = pd.Series(['john', 'mac'])
s2 = pd.Series([25, 30])
df = pd.concat([s1, s2], axis = 1)
df
# Out:
#       0   1
# 0  john  25
# 1   mac  30

# %%
import numpy as np
arr = np.array([1,2,3,-5,10])
arr
# Out:
# array([ 1,  2,  3, -5, 10])

# %%
ser = pd.Series(arr)
ser
# Out:
# 0     1
# 1     2
# 2     3
# 3    -5
# 4    10
# dtype: int64

# %%
# convert series into arr
arr1 = ser.values
arr1
# Out:
# array([ 1,  2,  3, -5, 10])

# %%
mydict = {'name':['john', 'michel', 'anil','ajay'],
          'dept': ['cse','civil','mechanical','entc'],
          'age': [20,30,40]}
mydict
# Out:
# {'name': ['john', 'michel', 'anil', 'ajay'],
#  'dept': ['cse', 'civil', 'mechanical', 'entc'],
#  'age': [20, 30, 40]}

# %%
arr2 = pd.Series(mydict)
arr2
# Out:
# name        [john, michel, anil, ajay]
# dept    [cse, civil, mechanical, entc]
# age                       [20, 30, 40]
# dtype: object

# %%
arr2['name'][0]
# Out:
# 'john'
